# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import cv2
import json

import skvideo
skvideo.setFFmpegPath("C:/Users/Cyril/Documents/MVA/S1/Deep Learning/TD3/ffmpeg/ffmpeg-4.1-win64-static/bin")
import skvideo.io

from keras.models import Sequential,model_from_json, Model
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D,Reshape,BatchNormalization, Input, Flatten
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# $\epsilon$ is essential because it is the exploration parameter. With $\epsilon = 0$, the agent will not learn and always take the best decision according to its learned policy. It will never improve its policy...
#
# $\epsilon$ to high will lead to a strategy too random which is good at first for exploration but bad for exploitation.

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the rat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature=0.3
epochs_train=10 # set small when debugging
epochs_test=10 # set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# The ```board``` is the map of the poisonnous cells and the cheese cells (0 for nothing, 0.5 for cheese, -1 for poison which coincide with the rewards). It is reset randomly at the beginning of an episode and when the rat passes through a cell (whether poison or cheese), he eats the content of the cell and it is set to 0.

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()

    def learned_act(self, s):
        return(np.random.randint(4))

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix=''):
    # Number of won games
    score = 0
        
    for e in range(epochs):
        s = env.reset()
        win,lose = 0,0
        game_over = False
        while not game_over:
            a = agent.learned_act(s)
            s, r, game_over = env.act(a)
            if r>=0:
                win += r
            else:
                lose -= r
        # Save as a mp4
        env.draw(prefix+str(e))

        # Update stats
        score = score + win - lose

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
    print('Final score: '+str(score/epochs))

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos('random0.mp4'))
# Out:
# Win/lose count 8.5/8.0. Average score (0.5)
# Win/lose count 7.0/13.0. Average score (-2.75)
# Win/lose count 7.5/15.0. Average score (-4.333333333333333)
# Win/lose count 11.5/14.0. Average score (-3.875)
# Win/lose count 8.5/13.0. Average score (-4.0)
# Win/lose count 8.5/15.0. Average score (-4.416666666666667)
# Win/lose count 8.5/14.0. Average score (-4.571428571428571)
# Win/lose count 12.5/13.0. Average score (-4.0625)
# Win/lose count 8.5/9.0. Average score (-3.6666666666666665)
# Win/lose count 9.5/17.0. Average score (-4.05)
# Final score: -4.05
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = []

    def remember(self, m):
        self.memory.append(m)
        self.memory = self.memory[-self.max_memory:]

    def random_access(self):
        return self.memory[np.random.randint(len(self.memory))]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16,n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        return np.argmax(self.model.predict(s.reshape(1,5,5,self.n_state))[0])

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size, 5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            s_, n_s_, a_, r_, game_over_ = self.memory.random_access()
            input_states[i] = s_
            target_q[i] = self.model.predict(s_.reshape(1,5,5,self.n_state))[0]
            if game_over_:
                target_q[i, a_] = r_
            else:
                target_q[i, a_] = r_ + self.discount * max(self.model.predict(n_s_.reshape(1,5,5,self.n_state))[0])

        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter
        target_q = np.clip(target_q, -3, 3)

        l = self.model.train_on_batch(input_states, target_q)
        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("adam", "mse")
        self.model = model

            
class DQN_FC(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        
        # NN Model
        
        input_layer = Input(shape=(5,5,self.n_state))
        flatten = Flatten()(input_layer)
        dense1 = Dense(64, activation="relu")(flatten)
        dense2 = Dense(32, activation="relu")(dense1)
        output = Dense(4, activation="softmax")(dense2)
        
        model = Model(input_layer, output)
        
        model.compile('adam', "mse")
        model.summary()
        self.model = model

# %%
epochs_train = 200

env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent, env, epochs_train, prefix='fc_train')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 5, 5, 2)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                3264
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 5,476
# Trainable params: 5,476
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/200 | Loss 0.0008 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 001/200 | Loss 0.0016 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 002/200 | Loss 0.0003 | Win/lose count 4.0/2.0 (2.0)
# Epoch 003/200 | Loss 0.0028 | Win/lose count 7.0/1.0 (6.0)
# Epoch 004/200 | Loss 0.0021 | Win/lose count 2.0/1.0 (1.0)
# Epoch 005/200 | Loss 0.0067 | Win/lose count 4.0/1.0 (3.0)
# Epoch 006/200 | Loss 0.0046 | Win/lose count 5.0/7.0 (-2.0)
# Epoch 007/200 | Loss 0.0045 | Win/lose count 7.5/4.0 (3.5)
# Epoch 008/200 | Loss 0.0077 | Win/lose count 5.0/1.0 (4.0)
# Epoch 009/200 | Loss 0.0033 | Win/lose count 6.5/4.0 (2.5)
# Epoch 010/200 | Loss 0.0035 | Win/lose count 5.5/6.0 (-0.5)
# Epoch 011/200 | Loss 0.0012 | Win/lose count 4.5/4.0 (0.5)
# Epoch 012/200 | Loss 0.0089 | Win/lose count 6.5/4.0 (2.5)
# Epoch 013/200 | Loss 0.0071 | Win/lose count 6.5/1.0 (5.5)
# Epoch 014/200 | Loss 0.0106 | Win/lose count 4.5/2.0 (2.5)
# Epoch 015/200 | Loss 0.0080 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 016/200 | Loss 0.0092 | Win/lose count 0.5/5.0 (-4.5)
# Epoch 017/200 | Loss 0.0139 | Win/lose count 4.5/3.0 (1.5)
# Epoch 018/200 | Loss 0.0062 | Win/lose count 5.5/5.0 (0.5)
# Epoch 019/200 | Loss 0.0042 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 020/200 | Loss 0.0065 | Win/lose count 4.0/1.0 (3.0)
# Epoch 021/200 | Loss 0.0063 | Win/lose count 6.0/2.0 (4.0)
# Epoch 022/200 | Loss 0.0085 | Win/lose count 8.5/5.0 (3.5)
# Epoch 023/200 | Loss 0.0044 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 024/200 | Loss 0.0051 | Win/lose count 5.5/1.0 (4.5)
# Epoch 025/200 | Loss 0.0045 | Win/lose count 3.5/2.0 (1.5)
# Epoch 026/200 | Loss 0.0065 | Win/lose count 12.0/0 (12.0)
# Epoch 027/200 | Loss 0.0102 | Win/lose count 5.0/3.0 (2.0)
# Epoch 028/200 | Loss 0.0071 | Win/lose count 5.5/2.0 (3.5)
# Epoch 029/200 | Loss 0.0057 | Win/lose count 7.5/4.0 (3.5)
# Epoch 030/200 | Loss 0.0114 | Win/lose count 7.5/5.0 (2.5)
# Epoch 031/200 | Loss 0.0118 | Win/lose count 9.0/3.0 (6.0)
# Epoch 032/200 | Loss 0.0059 | Win/lose count 9.5/7.0 (2.5)
# Epoch 033/200 | Loss 0.0078 | Win/lose count 13.0/4.0 (9.0)
# Epoch 034/200 | Loss 0.0087 | Win/lose count 18.5/1.0 (17.5)
# Epoch 035/200 | Loss 0.0111 | Win/lose count 7.5/6.0 (1.5)
# Epoch 036/200 | Loss 0.0059 | Win/lose count 16.5/0 (16.5)
# Epoch 037/200 | Loss 0.0082 | Win/lose count 4.0/2.0 (2.0)
# Epoch 038/200 | Loss 0.0090 | Win/lose count 10.0/3.0 (7.0)
# Epoch 039/200 | Loss 0.0164 | Win/lose count 19.0/3.0 (16.0)
# Epoch 040/200 | Loss 0.0116 | Win/lose count 12.0/2.0 (10.0)
# Epoch 041/200 | Loss 0.0061 | Win/lose count 10.5/3.0 (7.5)
# Epoch 042/200 | Loss 0.0243 | Win/lose count 17.5/6.0 (11.5)
# Epoch 043/200 | Loss 0.0115 | Win/lose count 14.5/3.0 (11.5)
# Epoch 044/200 | Loss 0.0158 | Win/lose count 15.0/5.0 (10.0)
# Epoch 045/200 | Loss 0.0074 | Win/lose count 6.5/4.0 (2.5)
# Epoch 046/200 | Loss 0.0288 | Win/lose count 5.5/1.0 (4.5)
# Epoch 047/200 | Loss 0.0092 | Win/lose count 9.0/4.0 (5.0)
# Epoch 048/200 | Loss 0.0063 | Win/lose count 10.0/6.0 (4.0)
# Epoch 049/200 | Loss 0.0092 | Win/lose count 0/1.0 (-1.0)
# Epoch 050/200 | Loss 0.0064 | Win/lose count 14.5/2.0 (12.5)
# Epoch 051/200 | Loss 0.0145 | Win/lose count 4.0/3.0 (1.0)
# Epoch 052/200 | Loss 0.0115 | Win/lose count 24.0/2.0 (22.0)
# Epoch 053/200 | Loss 0.0097 | Win/lose count 7.0/2.0 (5.0)
# Epoch 054/200 | Loss 0.0057 | Win/lose count 9.0/1.0 (8.0)
# Epoch 055/200 | Loss 0.0115 | Win/lose count 14.5/2.0 (12.5)
# Epoch 056/200 | Loss 0.0149 | Win/lose count 7.5/2.0 (5.5)
# Epoch 057/200 | Loss 0.0080 | Win/lose count 8.0/3.0 (5.0)
# Epoch 058/200 | Loss 0.0159 | Win/lose count 14.5/3.0 (11.5)
# Epoch 059/200 | Loss 0.0304 | Win/lose count 10.0/3.0 (7.0)
# Epoch 060/200 | Loss 0.0169 | Win/lose count 10.5/4.0 (6.5)
# Epoch 061/200 | Loss 0.0120 | Win/lose count 12.5/2.0 (10.5)
# Epoch 062/200 | Loss 0.0335 | Win/lose count 14.5/3.0 (11.5)
# Epoch 063/200 | Loss 0.0127 | Win/lose count 11.0/5.0 (6.0)
# Epoch 064/200 | Loss 0.0129 | Win/lose count 17.0/4.0 (13.0)
# Epoch 065/200 | Loss 0.0188 | Win/lose count 15.5/2.0 (13.5)
# Epoch 066/200 | Loss 0.0091 | Win/lose count 11.0/2.0 (9.0)
# Epoch 067/200 | Loss 0.0118 | Win/lose count 12.0/4.0 (8.0)
# Epoch 068/200 | Loss 0.0114 | Win/lose count 7.0/2.0 (5.0)
# Epoch 069/200 | Loss 0.0156 | Win/lose count 12.0/3.0 (9.0)
# Epoch 070/200 | Loss 0.0121 | Win/lose count 7.0/5.0 (2.0)
# Epoch 071/200 | Loss 0.0140 | Win/lose count 6.0/3.0 (3.0)
# Epoch 072/200 | Loss 0.0263 | Win/lose count 22.5/4.0 (18.5)
# Epoch 073/200 | Loss 0.0098 | Win/lose count 15.0/2.0 (13.0)
# Epoch 074/200 | Loss 0.0142 | Win/lose count 1.5/1.0 (0.5)
# Epoch 075/200 | Loss 0.0034 | Win/lose count 11.5/2.0 (9.5)
# Epoch 076/200 | Loss 0.0160 | Win/lose count 16.0/2.0 (14.0)
# Epoch 077/200 | Loss 0.0143 | Win/lose count 17.5/4.0 (13.5)
# Epoch 078/200 | Loss 0.0123 | Win/lose count 18.5/2.0 (16.5)
# Epoch 079/200 | Loss 0.0166 | Win/lose count 15.5/5.0 (10.5)
# Epoch 080/200 | Loss 0.0077 | Win/lose count 14.0/2.0 (12.0)
# Epoch 081/200 | Loss 0.0172 | Win/lose count 19.0/3.0 (16.0)
# Epoch 082/200 | Loss 0.0077 | Win/lose count 17.5/6.0 (11.5)
# Epoch 083/200 | Loss 0.0121 | Win/lose count 20.5/2.0 (18.5)
# Epoch 084/200 | Loss 0.0131 | Win/lose count 5.0/2.0 (3.0)
# Epoch 085/200 | Loss 0.0221 | Win/lose count 10.0/3.0 (7.0)
# Epoch 086/200 | Loss 0.0165 | Win/lose count 12.0/1.0 (11.0)
# Epoch 087/200 | Loss 0.0059 | Win/lose count 10.5/5.0 (5.5)
# Epoch 088/200 | Loss 0.0184 | Win/lose count 19.0/2.0 (17.0)
# Epoch 089/200 | Loss 0.0117 | Win/lose count 17.0/5.0 (12.0)
# Epoch 090/200 | Loss 0.0273 | Win/lose count 9.5/2.0 (7.5)
# Epoch 091/200 | Loss 0.0106 | Win/lose count 8.0/0 (8.0)
# Epoch 092/200 | Loss 0.0231 | Win/lose count 17.5/4.0 (13.5)
# Epoch 093/200 | Loss 0.0232 | Win/lose count 8.0/4.0 (4.0)
# Epoch 094/200 | Loss 0.0193 | Win/lose count 28.5/5.0 (23.5)
# Epoch 095/200 | Loss 0.0123 | Win/lose count 17.5/2.0 (15.5)
# Epoch 096/200 | Loss 0.0149 | Win/lose count 14.5/2.0 (12.5)
# Epoch 097/200 | Loss 0.0122 | Win/lose count 9.5/1.0 (8.5)
# Epoch 098/200 | Loss 0.0171 | Win/lose count 7.0/3.0 (4.0)
# Epoch 099/200 | Loss 0.0102 | Win/lose count 14.0/2.0 (12.0)
# Epoch 100/200 | Loss 0.0129 | Win/lose count 10.0/2.0 (8.0)
# Epoch 101/200 | Loss 0.0099 | Win/lose count 10.0/0 (10.0)
# Epoch 102/200 | Loss 0.0105 | Win/lose count 16.0/5.0 (11.0)
# Epoch 103/200 | Loss 0.0192 | Win/lose count 20.0/2.0 (18.0)
# Epoch 104/200 | Loss 0.0129 | Win/lose count 15.5/4.0 (11.5)
# Epoch 105/200 | Loss 0.0165 | Win/lose count 20.0/4.0 (16.0)
# Epoch 106/200 | Loss 0.0200 | Win/lose count 4.0/2.0 (2.0)
# Epoch 107/200 | Loss 0.0173 | Win/lose count 14.5/2.0 (12.5)
# Epoch 108/200 | Loss 0.0178 | Win/lose count 10.5/4.0 (6.5)
# Epoch 109/200 | Loss 0.0117 | Win/lose count 25.0/2.0 (23.0)
# Epoch 110/200 | Loss 0.0094 | Win/lose count 26.5/2.0 (24.5)
# Epoch 111/200 | Loss 0.0235 | Win/lose count 15.0/1.0 (14.0)
# Epoch 112/200 | Loss 0.0171 | Win/lose count 23.5/5.0 (18.5)
# Epoch 113/200 | Loss 0.0132 | Win/lose count 14.0/3.0 (11.0)
# Epoch 114/200 | Loss 0.0140 | Win/lose count 10.0/3.0 (7.0)
# Epoch 115/200 | Loss 0.0147 | Win/lose count 3.0/1.0 (2.0)
# Epoch 116/200 | Loss 0.0192 | Win/lose count 18.5/6.0 (12.5)
# Epoch 117/200 | Loss 0.0170 | Win/lose count 23.5/3.0 (20.5)
# Epoch 118/200 | Loss 0.0098 | Win/lose count 3.0/5.0 (-2.0)
# Epoch 119/200 | Loss 0.0043 | Win/lose count 6.5/2.0 (4.5)
# Epoch 120/200 | Loss 0.0110 | Win/lose count 8.0/2.0 (6.0)
# Epoch 121/200 | Loss 0.0106 | Win/lose count 12.0/1.0 (11.0)
# Epoch 122/200 | Loss 0.0198 | Win/lose count 11.0/3.0 (8.0)
# Epoch 123/200 | Loss 0.0125 | Win/lose count 20.5/4.0 (16.5)
# Epoch 124/200 | Loss 0.0145 | Win/lose count 12.5/6.0 (6.5)
# Epoch 125/200 | Loss 0.0166 | Win/lose count 12.5/3.0 (9.5)
# Epoch 126/200 | Loss 0.0139 | Win/lose count 14.5/2.0 (12.5)
# Epoch 127/200 | Loss 0.0121 | Win/lose count 16.0/5.0 (11.0)
# Epoch 128/200 | Loss 0.0100 | Win/lose count 21.0/8.0 (13.0)
# Epoch 129/200 | Loss 0.0246 | Win/lose count 17.5/2.0 (15.5)
# Epoch 130/200 | Loss 0.0042 | Win/lose count 16.0/7.0 (9.0)
# Epoch 131/200 | Loss 0.0152 | Win/lose count 8.0/3.0 (5.0)
# Epoch 132/200 | Loss 0.0157 | Win/lose count 10.0/2.0 (8.0)
# Epoch 133/200 | Loss 0.0100 | Win/lose count 21.5/5.0 (16.5)
# Epoch 134/200 | Loss 0.0142 | Win/lose count 16.5/3.0 (13.5)
# Epoch 135/200 | Loss 0.0152 | Win/lose count 25.5/4.0 (21.5)
# Epoch 136/200 | Loss 0.0174 | Win/lose count 10.5/7.0 (3.5)
# Epoch 137/200 | Loss 0.0134 | Win/lose count 14.0/1.0 (13.0)
# Epoch 138/200 | Loss 0.0070 | Win/lose count 9.0/1.0 (8.0)
# Epoch 139/200 | Loss 0.0184 | Win/lose count 10.5/2.0 (8.5)
# Epoch 140/200 | Loss 0.0070 | Win/lose count 11.5/3.0 (8.5)
# Epoch 141/200 | Loss 0.0093 | Win/lose count 7.5/0 (7.5)
# Epoch 142/200 | Loss 0.0039 | Win/lose count 15.5/5.0 (10.5)
# Epoch 143/200 | Loss 0.0083 | Win/lose count 7.0/3.0 (4.0)
# Epoch 144/200 | Loss 0.0098 | Win/lose count 19.0/2.0 (17.0)
# Epoch 145/200 | Loss 0.0133 | Win/lose count 19.0/5.0 (14.0)
# Epoch 146/200 | Loss 0.0143 | Win/lose count 19.0/2.0 (17.0)
# Epoch 147/200 | Loss 0.0156 | Win/lose count 9.0/5.0 (4.0)
# Epoch 148/200 | Loss 0.0079 | Win/lose count 10.0/0 (10.0)
# Epoch 149/200 | Loss 0.0305 | Win/lose count 13.0/3.0 (10.0)
# Epoch 150/200 | Loss 0.0201 | Win/lose count 9.0/0 (9.0)
# Epoch 151/200 | Loss 0.0238 | Win/lose count 5.0/1.0 (4.0)
# Epoch 152/200 | Loss 0.0143 | Win/lose count 19.5/6.0 (13.5)
# Epoch 153/200 | Loss 0.0112 | Win/lose count 16.0/2.0 (14.0)
# Epoch 154/200 | Loss 0.0140 | Win/lose count 15.5/1.0 (14.5)
# Epoch 155/200 | Loss 0.0197 | Win/lose count 19.5/1.0 (18.5)
# Epoch 156/200 | Loss 0.0079 | Win/lose count 18.0/1.0 (17.0)
# Epoch 157/200 | Loss 0.0175 | Win/lose count 10.5/3.0 (7.5)
# Epoch 158/200 | Loss 0.0158 | Win/lose count 14.0/2.0 (12.0)
# Epoch 159/200 | Loss 0.0190 | Win/lose count 8.5/5.0 (3.5)
# Epoch 160/200 | Loss 0.0040 | Win/lose count 10.0/1.0 (9.0)
# Epoch 161/200 | Loss 0.0140 | Win/lose count 15.0/4.0 (11.0)
# Epoch 162/200 | Loss 0.0161 | Win/lose count 13.0/2.0 (11.0)
# Epoch 163/200 | Loss 0.0166 | Win/lose count 17.5/2.0 (15.5)
# Epoch 164/200 | Loss 0.0123 | Win/lose count 7.0/3.0 (4.0)
# Epoch 165/200 | Loss 0.0185 | Win/lose count 18.5/4.0 (14.5)
# Epoch 166/200 | Loss 0.0130 | Win/lose count 17.5/3.0 (14.5)
# Epoch 167/200 | Loss 0.0116 | Win/lose count 12.5/6.0 (6.5)
# Epoch 168/200 | Loss 0.0142 | Win/lose count 14.0/3.0 (11.0)
# Epoch 169/200 | Loss 0.0258 | Win/lose count 8.5/1.0 (7.5)
# Epoch 170/200 | Loss 0.0205 | Win/lose count 22.0/2.0 (20.0)
# Epoch 171/200 | Loss 0.0141 | Win/lose count 18.5/6.0 (12.5)
# Epoch 172/200 | Loss 0.0112 | Win/lose count 12.5/4.0 (8.5)
# Epoch 173/200 | Loss 0.0174 | Win/lose count 15.0/2.0 (13.0)
# Epoch 174/200 | Loss 0.0117 | Win/lose count 12.5/4.0 (8.5)
# Epoch 175/200 | Loss 0.0112 | Win/lose count 19.0/2.0 (17.0)
# Epoch 176/200 | Loss 0.0169 | Win/lose count 14.5/3.0 (11.5)
# Epoch 177/200 | Loss 0.0428 | Win/lose count 20.5/7.0 (13.5)
# Epoch 178/200 | Loss 0.0315 | Win/lose count 12.0/2.0 (10.0)
# Epoch 179/200 | Loss 0.0093 | Win/lose count 9.0/2.0 (7.0)
# Epoch 180/200 | Loss 0.0114 | Win/lose count 18.0/9.0 (9.0)
# Epoch 181/200 | Loss 0.0047 | Win/lose count 19.5/5.0 (14.5)
# Epoch 182/200 | Loss 0.0184 | Win/lose count 14.5/1.0 (13.5)
# Epoch 183/200 | Loss 0.0221 | Win/lose count 19.5/8.0 (11.5)
# Epoch 184/200 | Loss 0.0129 | Win/lose count 10.5/2.0 (8.5)
# Epoch 185/200 | Loss 0.0079 | Win/lose count 14.0/2.0 (12.0)
# Epoch 186/200 | Loss 0.0098 | Win/lose count 15.5/2.0 (13.5)
# Epoch 187/200 | Loss 0.0099 | Win/lose count 12.5/1.0 (11.5)
# Epoch 188/200 | Loss 0.0109 | Win/lose count 11.5/3.0 (8.5)
# Epoch 189/200 | Loss 0.0088 | Win/lose count 16.0/1.0 (15.0)
# Epoch 190/200 | Loss 0.0168 | Win/lose count 24.0/3.0 (21.0)
# Epoch 191/200 | Loss 0.0068 | Win/lose count 16.5/3.0 (13.5)
# Epoch 192/200 | Loss 0.0158 | Win/lose count 11.0/2.0 (9.0)
# Epoch 193/200 | Loss 0.0085 | Win/lose count 5.0/2.0 (3.0)
# Epoch 194/200 | Loss 0.0121 | Win/lose count 17.5/6.0 (11.5)
# Epoch 195/200 | Loss 0.0277 | Win/lose count 12.0/4.0 (8.0)
# Epoch 196/200 | Loss 0.0164 | Win/lose count 8.0/2.0 (6.0)
# Epoch 197/200 | Loss 0.0093 | Win/lose count 11.5/5.0 (6.5)
# Epoch 198/200 | Loss 0.0306 | Win/lose count 18.5/4.0 (14.5)
# Epoch 199/200 | Loss 0.0101 | Win/lose count 18.5/3.0 (15.5)

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
class DQN_CNN(DQN):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
        
        input_layer = Input(shape=(5,5,self.n_state))
        conv1 = Conv2D(128, 3, activation="relu")(input_layer)
        conv2 = Conv2D(256, 3, activation="relu")(conv1)
        flatten = Flatten()(conv2)
        output = Dense(4, activation="softmax")(flatten)
        
        model = Model(input_layer, output)
        
        model.compile("adam", "mse")
        model.summary()
        self.model = model

# %%
epochs_train = 200

env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent,env,epochs_train,prefix='cnn_train')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 5, 5, 2)           0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 3, 3, 128)         2432
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 1, 256)         295168
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 298,628
# Trainable params: 298,628
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/200 | Loss 0.0029 | Win/lose count 3.0/0 (3.0)
# Epoch 001/200 | Loss 0.0073 | Win/lose count 4.0/3.0 (1.0)
# Epoch 002/200 | Loss 0.0187 | Win/lose count 4.0/4.0 (0.0)
# Epoch 003/200 | Loss 0.0013 | Win/lose count 2.5/1.0 (1.5)
# Epoch 004/200 | Loss 0.0013 | Win/lose count 3.5/7.0 (-3.5)
# Epoch 005/200 | Loss 0.0050 | Win/lose count 4.5/5.0 (-0.5)
# Epoch 006/200 | Loss 0.0035 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 007/200 | Loss 0.0014 | Win/lose count 3.0/2.0 (1.0)
# Epoch 008/200 | Loss 0.0005 | Win/lose count 2.0/0 (2.0)
# Epoch 009/200 | Loss 0.0061 | Win/lose count 5.0/3.0 (2.0)
# Epoch 010/200 | Loss 0.0056 | Win/lose count 5.0/1.0 (4.0)
# Epoch 011/200 | Loss 0.0043 | Win/lose count 0.5/4.0 (-3.5)
# Epoch 012/200 | Loss 0.0021 | Win/lose count 3.0/2.0 (1.0)
# Epoch 013/200 | Loss 0.0015 | Win/lose count 3.0/3.0 (0.0)
# Epoch 014/200 | Loss 0.0036 | Win/lose count 4.0/1.0 (3.0)
# Epoch 015/200 | Loss 0.0020 | Win/lose count 4.0/3.0 (1.0)
# Epoch 016/200 | Loss 0.0068 | Win/lose count 5.5/4.0 (1.5)
# Epoch 017/200 | Loss 0.0051 | Win/lose count 2.5/1.0 (1.5)
# Epoch 018/200 | Loss 0.0048 | Win/lose count 7.0/4.0 (3.0)
# Epoch 019/200 | Loss 0.0047 | Win/lose count 3.0/1.0 (2.0)
# Epoch 020/200 | Loss 0.0071 | Win/lose count 6.0/0 (6.0)
# Epoch 021/200 | Loss 0.0031 | Win/lose count 7.5/1.0 (6.5)
# Epoch 022/200 | Loss 0.0044 | Win/lose count 5.0/1.0 (4.0)
# Epoch 023/200 | Loss 0.0064 | Win/lose count 6.5/4.0 (2.5)
# Epoch 024/200 | Loss 0.0054 | Win/lose count 5.5/3.0 (2.5)
# Epoch 025/200 | Loss 0.0103 | Win/lose count 9.0/3.0 (6.0)
# Epoch 026/200 | Loss 0.0089 | Win/lose count 11.0/2.0 (9.0)
# Epoch 027/200 | Loss 0.0082 | Win/lose count 8.5/2.0 (6.5)
# Epoch 028/200 | Loss 0.0056 | Win/lose count 15.5/1.0 (14.5)
# Epoch 029/200 | Loss 0.0045 | Win/lose count 11.5/3.0 (8.5)
# Epoch 030/200 | Loss 0.0094 | Win/lose count 10.0/1.0 (9.0)
# Epoch 031/200 | Loss 0.0189 | Win/lose count 11.5/1.0 (10.5)
# Epoch 032/200 | Loss 0.0050 | Win/lose count 8.0/2.0 (6.0)
# Epoch 033/200 | Loss 0.0101 | Win/lose count 9.0/5.0 (4.0)
# Epoch 034/200 | Loss 0.0026 | Win/lose count 21.0/4.0 (17.0)
# Epoch 035/200 | Loss 0.0062 | Win/lose count 12.5/4.0 (8.5)
# Epoch 036/200 | Loss 0.0072 | Win/lose count 17.5/3.0 (14.5)
# Epoch 037/200 | Loss 0.0172 | Win/lose count 8.5/2.0 (6.5)
# Epoch 038/200 | Loss 0.0051 | Win/lose count 13.5/5.0 (8.5)
# Epoch 039/200 | Loss 0.0094 | Win/lose count 13.0/1.0 (12.0)
# Epoch 040/200 | Loss 0.0110 | Win/lose count 14.0/5.0 (9.0)
# Epoch 041/200 | Loss 0.0137 | Win/lose count 9.0/2.0 (7.0)
# Epoch 042/200 | Loss 0.0219 | Win/lose count 14.0/5.0 (9.0)
# Epoch 043/200 | Loss 0.0127 | Win/lose count 14.0/7.0 (7.0)
# Epoch 044/200 | Loss 0.0153 | Win/lose count 23.0/3.0 (20.0)
# Epoch 045/200 | Loss 0.0201 | Win/lose count 12.5/4.0 (8.5)
# Epoch 046/200 | Loss 0.0085 | Win/lose count 19.5/3.0 (16.5)
# Epoch 047/200 | Loss 0.0118 | Win/lose count 12.5/6.0 (6.5)
# Epoch 048/200 | Loss 0.0238 | Win/lose count 22.5/3.0 (19.5)
# Epoch 049/200 | Loss 0.0154 | Win/lose count 18.5/6.0 (12.5)
# Epoch 050/200 | Loss 0.0160 | Win/lose count 15.0/2.0 (13.0)
# Epoch 051/200 | Loss 0.0265 | Win/lose count 15.5/4.0 (11.5)
# Epoch 052/200 | Loss 0.0058 | Win/lose count 13.0/6.0 (7.0)
# Epoch 053/200 | Loss 0.0117 | Win/lose count 27.0/5.0 (22.0)
# Epoch 054/200 | Loss 0.0180 | Win/lose count 23.0/3.0 (20.0)
# Epoch 055/200 | Loss 0.0121 | Win/lose count 15.0/4.0 (11.0)
# Epoch 056/200 | Loss 0.0198 | Win/lose count 13.0/3.0 (10.0)
# Epoch 057/200 | Loss 0.0279 | Win/lose count 21.5/2.0 (19.5)
# Epoch 058/200 | Loss 0.0114 | Win/lose count 15.5/4.0 (11.5)
# Epoch 059/200 | Loss 0.0125 | Win/lose count 17.0/4.0 (13.0)
# Epoch 060/200 | Loss 0.0130 | Win/lose count 11.5/3.0 (8.5)
# Epoch 061/200 | Loss 0.0106 | Win/lose count 22.5/3.0 (19.5)
# Epoch 062/200 | Loss 0.0155 | Win/lose count 22.0/4.0 (18.0)
# Epoch 063/200 | Loss 0.0089 | Win/lose count 15.0/0 (15.0)
# Epoch 064/200 | Loss 0.0099 | Win/lose count 11.0/3.0 (8.0)
# Epoch 065/200 | Loss 0.0172 | Win/lose count 8.5/6.0 (2.5)
# Epoch 066/200 | Loss 0.0130 | Win/lose count 14.0/3.0 (11.0)
# Epoch 067/200 | Loss 0.0097 | Win/lose count 22.5/1.0 (21.5)
# Epoch 068/200 | Loss 0.0269 | Win/lose count 13.5/3.0 (10.5)
# Epoch 069/200 | Loss 0.0324 | Win/lose count 18.5/3.0 (15.5)
# Epoch 070/200 | Loss 0.0170 | Win/lose count 10.0/2.0 (8.0)
# Epoch 071/200 | Loss 0.0118 | Win/lose count 16.5/4.0 (12.5)
# Epoch 072/200 | Loss 0.0084 | Win/lose count 16.0/9.0 (7.0)
# Epoch 073/200 | Loss 0.0254 | Win/lose count 16.0/5.0 (11.0)
# Epoch 074/200 | Loss 0.0210 | Win/lose count 18.5/2.0 (16.5)
# Epoch 075/200 | Loss 0.0208 | Win/lose count 15.5/5.0 (10.5)
# Epoch 076/200 | Loss 0.0117 | Win/lose count 20.0/2.0 (18.0)
# Epoch 077/200 | Loss 0.0244 | Win/lose count 16.5/3.0 (13.5)
# Epoch 078/200 | Loss 0.0173 | Win/lose count 16.5/3.0 (13.5)
# Epoch 079/200 | Loss 0.0119 | Win/lose count 20.0/6.0 (14.0)
# Epoch 080/200 | Loss 0.0180 | Win/lose count 26.0/4.0 (22.0)
# Epoch 081/200 | Loss 0.0223 | Win/lose count 22.5/6.0 (16.5)
# Epoch 082/200 | Loss 0.0141 | Win/lose count 19.5/0 (19.5)
# Epoch 083/200 | Loss 0.0191 | Win/lose count 17.5/8.0 (9.5)
# Epoch 084/200 | Loss 0.0367 | Win/lose count 19.5/5.0 (14.5)
# Epoch 085/200 | Loss 0.0133 | Win/lose count 9.0/2.0 (7.0)
# Epoch 086/200 | Loss 0.0132 | Win/lose count 18.5/5.0 (13.5)
# Epoch 087/200 | Loss 0.0148 | Win/lose count 22.5/6.0 (16.5)
# Epoch 088/200 | Loss 0.0216 | Win/lose count 14.5/2.0 (12.5)
# Epoch 089/200 | Loss 0.0152 | Win/lose count 8.5/2.0 (6.5)
# Epoch 090/200 | Loss 0.0110 | Win/lose count 20.0/1.0 (19.0)
# Epoch 091/200 | Loss 0.0277 | Win/lose count 20.0/5.0 (15.0)
# Epoch 092/200 | Loss 0.0261 | Win/lose count 23.0/5.0 (18.0)
# Epoch 093/200 | Loss 0.0188 | Win/lose count 21.5/4.0 (17.5)
# Epoch 094/200 | Loss 0.0355 | Win/lose count 16.5/2.0 (14.5)
# Epoch 095/200 | Loss 0.0345 | Win/lose count 23.0/3.0 (20.0)
# Epoch 096/200 | Loss 0.0162 | Win/lose count 24.5/6.0 (18.5)
# Epoch 097/200 | Loss 0.0142 | Win/lose count 12.5/3.0 (9.5)
# Epoch 098/200 | Loss 0.0143 | Win/lose count 22.5/4.0 (18.5)
# Epoch 099/200 | Loss 0.0219 | Win/lose count 24.5/3.0 (21.5)
# Epoch 100/200 | Loss 0.0267 | Win/lose count 17.5/8.0 (9.5)
# Epoch 101/200 | Loss 0.0294 | Win/lose count 22.5/3.0 (19.5)
# Epoch 102/200 | Loss 0.0081 | Win/lose count 19.0/3.0 (16.0)
# Epoch 103/200 | Loss 0.0310 | Win/lose count 20.5/5.0 (15.5)
# Epoch 104/200 | Loss 0.0193 | Win/lose count 21.0/4.0 (17.0)
# Epoch 105/200 | Loss 0.0178 | Win/lose count 22.0/10.0 (12.0)
# Epoch 106/200 | Loss 0.0222 | Win/lose count 22.0/3.0 (19.0)
# Epoch 107/200 | Loss 0.0318 | Win/lose count 23.0/5.0 (18.0)
# Epoch 108/200 | Loss 0.0392 | Win/lose count 23.0/3.0 (20.0)
# Epoch 109/200 | Loss 0.0266 | Win/lose count 23.0/3.0 (20.0)
# Epoch 110/200 | Loss 0.0061 | Win/lose count 20.0/4.0 (16.0)
# Epoch 111/200 | Loss 0.0255 | Win/lose count 6.0/0 (6.0)
# Epoch 112/200 | Loss 0.0082 | Win/lose count 21.0/5.0 (16.0)
# Epoch 113/200 | Loss 0.0197 | Win/lose count 18.5/3.0 (15.5)
# Epoch 114/200 | Loss 0.0219 | Win/lose count 9.5/3.0 (6.5)
# Epoch 115/200 | Loss 0.0192 | Win/lose count 21.5/6.0 (15.5)
# Epoch 116/200 | Loss 0.0166 | Win/lose count 17.5/3.0 (14.5)
# Epoch 117/200 | Loss 0.0085 | Win/lose count 18.0/3.0 (15.0)
# Epoch 118/200 | Loss 0.0120 | Win/lose count 16.0/3.0 (13.0)
# Epoch 119/200 | Loss 0.0182 | Win/lose count 11.5/3.0 (8.5)
# Epoch 120/200 | Loss 0.0256 | Win/lose count 16.0/3.0 (13.0)
# Epoch 121/200 | Loss 0.0172 | Win/lose count 26.5/4.0 (22.5)
# Epoch 122/200 | Loss 0.0176 | Win/lose count 19.5/3.0 (16.5)
# Epoch 123/200 | Loss 0.0170 | Win/lose count 10.5/2.0 (8.5)
# Epoch 124/200 | Loss 0.0133 | Win/lose count 17.5/4.0 (13.5)
# Epoch 125/200 | Loss 0.0251 | Win/lose count 19.5/7.0 (12.5)
# Epoch 126/200 | Loss 0.0055 | Win/lose count 11.5/4.0 (7.5)
# Epoch 127/200 | Loss 0.0222 | Win/lose count 17.0/2.0 (15.0)
# Epoch 128/200 | Loss 0.0138 | Win/lose count 18.0/2.0 (16.0)
# Epoch 129/200 | Loss 0.0072 | Win/lose count 14.0/2.0 (12.0)
# Epoch 130/200 | Loss 0.0068 | Win/lose count 15.5/5.0 (10.5)
# Epoch 131/200 | Loss 0.0375 | Win/lose count 7.0/2.0 (5.0)
# Epoch 132/200 | Loss 0.0172 | Win/lose count 9.5/2.0 (7.5)
# Epoch 133/200 | Loss 0.0159 | Win/lose count 15.5/3.0 (12.5)
# Epoch 134/200 | Loss 0.0180 | Win/lose count 17.5/5.0 (12.5)
# Epoch 135/200 | Loss 0.0124 | Win/lose count 14.5/2.0 (12.5)
# Epoch 136/200 | Loss 0.0227 | Win/lose count 26.5/5.0 (21.5)
# Epoch 137/200 | Loss 0.0198 | Win/lose count 17.0/5.0 (12.0)
# Epoch 138/200 | Loss 0.0214 | Win/lose count 10.0/4.0 (6.0)
# Epoch 139/200 | Loss 0.0294 | Win/lose count 16.5/5.0 (11.5)
# Epoch 140/200 | Loss 0.0107 | Win/lose count 14.5/2.0 (12.5)
# Epoch 141/200 | Loss 0.0252 | Win/lose count 11.5/3.0 (8.5)
# Epoch 142/200 | Loss 0.0083 | Win/lose count 21.5/2.0 (19.5)
# Epoch 143/200 | Loss 0.0192 | Win/lose count 16.0/5.0 (11.0)
# Epoch 144/200 | Loss 0.0147 | Win/lose count 9.0/3.0 (6.0)
# Epoch 145/200 | Loss 0.0200 | Win/lose count 7.5/0 (7.5)
# Epoch 146/200 | Loss 0.0156 | Win/lose count 26.0/1.0 (25.0)
# Epoch 147/200 | Loss 0.0419 | Win/lose count 14.0/4.0 (10.0)
# Epoch 148/200 | Loss 0.0127 | Win/lose count 23.5/4.0 (19.5)
# Epoch 149/200 | Loss 0.0076 | Win/lose count 24.0/3.0 (21.0)
# Epoch 150/200 | Loss 0.0217 | Win/lose count 19.5/2.0 (17.5)
# Epoch 151/200 | Loss 0.0166 | Win/lose count 23.0/7.0 (16.0)
# Epoch 152/200 | Loss 0.0178 | Win/lose count 27.0/6.0 (21.0)
# Epoch 153/200 | Loss 0.0176 | Win/lose count 21.0/1.0 (20.0)
# Epoch 154/200 | Loss 0.0212 | Win/lose count 13.5/3.0 (10.5)
# Epoch 155/200 | Loss 0.0193 | Win/lose count 18.5/3.0 (15.5)
# Epoch 156/200 | Loss 0.0294 | Win/lose count 14.0/4.0 (10.0)
# Epoch 157/200 | Loss 0.0332 | Win/lose count 18.5/5.0 (13.5)
# Epoch 158/200 | Loss 0.0543 | Win/lose count 16.0/3.0 (13.0)
# Epoch 159/200 | Loss 0.0145 | Win/lose count 23.0/3.0 (20.0)
# Epoch 160/200 | Loss 0.0142 | Win/lose count 17.5/2.0 (15.5)
# Epoch 161/200 | Loss 0.0166 | Win/lose count 11.0/4.0 (7.0)
# Epoch 162/200 | Loss 0.0221 | Win/lose count 12.5/2.0 (10.5)
# Epoch 163/200 | Loss 0.0118 | Win/lose count 21.0/2.0 (19.0)
# Epoch 164/200 | Loss 0.0169 | Win/lose count 18.5/3.0 (15.5)
# Epoch 165/200 | Loss 0.0209 | Win/lose count 16.5/4.0 (12.5)
# Epoch 166/200 | Loss 0.0203 | Win/lose count 13.5/6.0 (7.5)
# Epoch 167/200 | Loss 0.0451 | Win/lose count 16.0/1.0 (15.0)
# Epoch 168/200 | Loss 0.0305 | Win/lose count 13.0/2.0 (11.0)
# Epoch 169/200 | Loss 0.0223 | Win/lose count 26.0/2.0 (24.0)
# Epoch 170/200 | Loss 0.0421 | Win/lose count 13.5/4.0 (9.5)
# Epoch 171/200 | Loss 0.0228 | Win/lose count 7.5/2.0 (5.5)
# Epoch 172/200 | Loss 0.0265 | Win/lose count 8.5/2.0 (6.5)
# Epoch 173/200 | Loss 0.0195 | Win/lose count 17.0/9.0 (8.0)
# Epoch 174/200 | Loss 0.0204 | Win/lose count 20.5/3.0 (17.5)
# Epoch 175/200 | Loss 0.0132 | Win/lose count 23.0/3.0 (20.0)
# Epoch 176/200 | Loss 0.0133 | Win/lose count 16.5/4.0 (12.5)
# Epoch 177/200 | Loss 0.0359 | Win/lose count 26.0/4.0 (22.0)
# Epoch 178/200 | Loss 0.0095 | Win/lose count 22.0/6.0 (16.0)
# Epoch 179/200 | Loss 0.0120 | Win/lose count 5.5/1.0 (4.5)
# Epoch 180/200 | Loss 0.0148 | Win/lose count 15.5/3.0 (12.5)
# Epoch 181/200 | Loss 0.0139 | Win/lose count 22.0/4.0 (18.0)
# Epoch 182/200 | Loss 0.0256 | Win/lose count 15.0/7.0 (8.0)
# Epoch 183/200 | Loss 0.0080 | Win/lose count 19.5/3.0 (16.5)
# Epoch 184/200 | Loss 0.0306 | Win/lose count 13.5/4.0 (9.5)
# Epoch 185/200 | Loss 0.0328 | Win/lose count 28.0/4.0 (24.0)
# Epoch 186/200 | Loss 0.0102 | Win/lose count 9.0/2.0 (7.0)
# Epoch 187/200 | Loss 0.0192 | Win/lose count 14.0/4.0 (10.0)
# Epoch 188/200 | Loss 0.0235 | Win/lose count 10.5/2.0 (8.5)
# Epoch 189/200 | Loss 0.0126 | Win/lose count 28.5/5.0 (23.5)
# Epoch 190/200 | Loss 0.0257 | Win/lose count 10.5/2.0 (8.5)
# Epoch 191/200 | Loss 0.0151 | Win/lose count 14.5/5.0 (9.5)
# Epoch 192/200 | Loss 0.0118 | Win/lose count 13.5/3.0 (10.5)
# Epoch 193/200 | Loss 0.0139 | Win/lose count 24.5/3.0 (21.5)
# Epoch 194/200 | Loss 0.0220 | Win/lose count 22.0/5.0 (17.0)
# Epoch 195/200 | Loss 0.0078 | Win/lose count 6.0/1.0 (5.0)
# Epoch 196/200 | Loss 0.0105 | Win/lose count 13.0/3.0 (10.0)
# Epoch 197/200 | Loss 0.0150 | Win/lose count 22.5/6.0 (16.5)
# Epoch 198/200 | Loss 0.0187 | Win/lose count 17.5/4.0 (13.5)
# Epoch 199/200 | Loss 0.0274 | Win/lose count 23.5/1.0 (22.5)

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.3)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_fc.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 5, 5, 2)           0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 128)         2432
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 256)         295168
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 298,628
# Trainable params: 298,628
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 5, 5, 2)           0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                3264
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 5,476
# Trainable params: 5,476
# Non-trainable params: 0
# _________________________________________________________________
# Test of the CNN
# Win/lose count 8.0/0. Average score (8.0)
# Win/lose count 8.0/0. Average score (8.0)
# Win/lose count 1.5/1.0. Average score (5.5)
# Win/lose count 12.5/1.0. Average score (7.0)
# Win/lose count 13.0/1.0. Average score (8.0)
# Win/lose count 8.0/0. Average score (8.0)
# Win/lose count 6.5/0. Average score (7.785714285714286)
# Win/lose count 2.5/0. Average score (7.125)
# Win/lose count 11.5/1.0. Average score (7.5)
# Win/lose count 14.0/1.0. Average score (8.05)
# Final score: 8.05
# Test of the FC
# Win/lose count 4.5/0. Average score (4.5)
# Win/lose count 21.5/0. Average score (13.0)
# Win/lose count 5.0/0. Average score (10.333333333333334)
# Win/lose count 8.0/1.0. Average score (9.5)
# Win/lose count 1.0/0. Average score (7.8)
# Win/lose count 21.0/0. Average score (10.0)
# Win/lose count 1.0/0. Average score (8.714285714285714)
# Win/lose count 12.0/0. Average score (9.125)
# Win/lose count 18.0/0. Average score (10.11111111111111)
# Win/lose count 5.0/0. Average score (9.6)
# Final score: 9.6

# %%
HTML(display_videos('cnn_test1.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
HTML(display_videos('fc_test3.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# The main issue is that when the surrounding area of the rat is cleaned (without cheese remaining), the agent doesn't know what to do and tend to be stuck in a loop until the end of the algorithm. Because of this, the rat misses a lot of cheese in fully unexplored areas.

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %%
class EnvironmentExploring(object):   
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the rat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action, train = False):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = 0
        if train:
            reward = -self.malus_position[self.x, self.y]
        self.malus_position[self.x, self.y] += 0.1

        reward = reward + self.board[self.x, self.y]
        
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time

        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0
        
        self.malus_position = np.zeros((self.grid_size, self.grid_size))

        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %%
def train_explore(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action, train=True)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {:.1f}/{:.1f} ({:.1f})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %%
# Training
epochs_train = 200
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32,n_state=3)
train_explore(agent, env, epochs_train, prefix='cnn_train_explore')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 5, 5, 3)           0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 128)         3584
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 256)         295168
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 299,780
# Trainable params: 299,780
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/200 | Loss 0.0143 | Win/lose count 9.5/48.4 (-38.9)
# Epoch 001/200 | Loss 0.0105 | Win/lose count 17.0/32.9 (-15.9)
# Epoch 002/200 | Loss 0.0108 | Win/lose count 19.5/26.2 (-6.7)
# Epoch 003/200 | Loss 0.0170 | Win/lose count 19.5/22.4 (-2.9)
# Epoch 004/200 | Loss 0.0070 | Win/lose count 21.0/18.9 (2.1)
# Epoch 005/200 | Loss 0.0068 | Win/lose count 21.0/24.4 (-3.4)
# Epoch 006/200 | Loss 0.0165 | Win/lose count 24.0/18.8 (5.2)
# Epoch 007/200 | Loss 0.0177 | Win/lose count 18.5/21.4 (-2.9)
# Epoch 008/200 | Loss 0.0181 | Win/lose count 24.5/20.3 (4.2)
# Epoch 009/200 | Loss 0.0112 | Win/lose count 22.0/21.2 (0.8)
# Epoch 010/200 | Loss 0.0190 | Win/lose count 19.5/26.4 (-6.9)
# Epoch 011/200 | Loss 0.0126 | Win/lose count 23.0/17.5 (5.5)
# Epoch 012/200 | Loss 0.0094 | Win/lose count 17.5/25.3 (-7.8)
# Epoch 013/200 | Loss 0.0150 | Win/lose count 13.5/22.5 (-9.0)
# Epoch 014/200 | Loss 0.0135 | Win/lose count 25.0/18.8 (6.2)
# Epoch 015/200 | Loss 0.0140 | Win/lose count 26.5/10.7 (15.8)
# Epoch 016/200 | Loss 0.0267 | Win/lose count 24.0/18.9 (5.1)
# Epoch 017/200 | Loss 0.0332 | Win/lose count 23.5/14.7 (8.8)
# Epoch 018/200 | Loss 0.0132 | Win/lose count 19.0/27.4 (-8.4)
# Epoch 019/200 | Loss 0.0140 | Win/lose count 21.0/28.8 (-7.8)
# Epoch 020/200 | Loss 0.0169 | Win/lose count 17.0/22.0 (-5.0)
# Epoch 021/200 | Loss 0.0206 | Win/lose count 23.5/17.6 (5.9)
# Epoch 022/200 | Loss 0.0203 | Win/lose count 24.5/21.1 (3.4)
# Epoch 023/200 | Loss 0.0248 | Win/lose count 19.0/25.1 (-6.1)
# Epoch 024/200 | Loss 0.0247 | Win/lose count 15.5/20.3 (-4.8)
# Epoch 025/200 | Loss 0.0160 | Win/lose count 17.5/15.1 (2.4)
# Epoch 026/200 | Loss 0.0191 | Win/lose count 16.5/24.4 (-7.9)
# Epoch 027/200 | Loss 0.0209 | Win/lose count 20.5/16.9 (3.6)
# Epoch 028/200 | Loss 0.0231 | Win/lose count 18.0/26.8 (-8.8)
# Epoch 029/200 | Loss 0.0127 | Win/lose count 20.5/19.9 (0.6)
# Epoch 030/200 | Loss 0.0119 | Win/lose count 25.5/16.1 (9.4)
# Epoch 031/200 | Loss 0.0217 | Win/lose count 20.5/28.0 (-7.5)
# Epoch 032/200 | Loss 0.0180 | Win/lose count 20.5/28.5 (-8.0)
# Epoch 033/200 | Loss 0.0095 | Win/lose count 23.0/29.3 (-6.3)
# Epoch 034/200 | Loss 0.0207 | Win/lose count 23.5/17.6 (5.9)
# Epoch 035/200 | Loss 0.0166 | Win/lose count 20.5/18.0 (2.5)
# Epoch 036/200 | Loss 0.0272 | Win/lose count 17.5/28.7 (-11.2)
# Epoch 037/200 | Loss 0.0127 | Win/lose count 21.0/23.2 (-2.2)
# Epoch 038/200 | Loss 0.0109 | Win/lose count 20.5/27.8 (-7.3)
# Epoch 039/200 | Loss 0.0247 | Win/lose count 28.0/17.8 (10.2)
# Epoch 040/200 | Loss 0.0132 | Win/lose count 21.0/21.8 (-0.8)
# Epoch 041/200 | Loss 0.0086 | Win/lose count 23.5/15.2 (8.3)
# Epoch 042/200 | Loss 0.0155 | Win/lose count 25.5/26.2 (-0.7)
# Epoch 043/200 | Loss 0.0137 | Win/lose count 20.0/13.6 (6.4)
# Epoch 044/200 | Loss 0.0064 | Win/lose count 25.0/23.4 (1.6)
# Epoch 045/200 | Loss 0.0177 | Win/lose count 21.5/19.0 (2.5)
# Epoch 046/200 | Loss 0.0368 | Win/lose count 29.5/15.1 (14.4)
# Epoch 047/200 | Loss 0.0347 | Win/lose count 22.5/13.8 (8.7)
# Epoch 048/200 | Loss 0.0195 | Win/lose count 23.0/19.0 (4.0)
# Epoch 049/200 | Loss 0.0231 | Win/lose count 27.5/15.0 (12.5)
# Epoch 050/200 | Loss 0.0146 | Win/lose count 21.0/20.1 (0.9)
# Epoch 051/200 | Loss 0.0141 | Win/lose count 23.5/17.3 (6.2)
# Epoch 052/200 | Loss 0.0254 | Win/lose count 25.5/21.8 (3.7)
# Epoch 053/200 | Loss 0.0071 | Win/lose count 25.0/24.0 (1.0)
# Epoch 054/200 | Loss 0.0123 | Win/lose count 27.0/17.4 (9.6)
# Epoch 055/200 | Loss 0.0304 | Win/lose count 22.5/22.6 (-0.1)
# Epoch 056/200 | Loss 0.0250 | Win/lose count 18.5/18.7 (-0.2)
# Epoch 057/200 | Loss 0.0126 | Win/lose count 28.5/17.6 (10.9)
# Epoch 058/200 | Loss 0.0181 | Win/lose count 22.5/22.5 (-0.0)
# Epoch 059/200 | Loss 0.0371 | Win/lose count 20.0/19.2 (0.8)
# Epoch 060/200 | Loss 0.0145 | Win/lose count 25.5/18.4 (7.1)
# Epoch 061/200 | Loss 0.0191 | Win/lose count 20.5/15.9 (4.6)
# Epoch 062/200 | Loss 0.0167 | Win/lose count 23.0/20.2 (2.8)
# Epoch 063/200 | Loss 0.0087 | Win/lose count 24.5/19.9 (4.6)
# Epoch 064/200 | Loss 0.0127 | Win/lose count 28.0/14.6 (13.4)
# Epoch 065/200 | Loss 0.0174 | Win/lose count 20.0/17.3 (2.7)
# Epoch 066/200 | Loss 0.0108 | Win/lose count 20.5/22.5 (-2.0)
# Epoch 067/200 | Loss 0.0150 | Win/lose count 22.5/16.2 (6.3)
# Epoch 068/200 | Loss 0.0116 | Win/lose count 22.0/25.1 (-3.1)
# Epoch 069/200 | Loss 0.0181 | Win/lose count 26.5/19.3 (7.2)
# Epoch 070/200 | Loss 0.0345 | Win/lose count 26.5/22.8 (3.7)
# Epoch 071/200 | Loss 0.0146 | Win/lose count 27.5/19.5 (8.0)
# Epoch 072/200 | Loss 0.0142 | Win/lose count 16.5/17.9 (-1.4)
# Epoch 073/200 | Loss 0.0146 | Win/lose count 23.5/25.4 (-1.9)
# Epoch 074/200 | Loss 0.0266 | Win/lose count 24.0/25.3 (-1.3)
# Epoch 075/200 | Loss 0.0241 | Win/lose count 22.0/14.2 (7.8)
# Epoch 076/200 | Loss 0.0168 | Win/lose count 19.5/21.9 (-2.4)
# Epoch 077/200 | Loss 0.0232 | Win/lose count 26.5/20.1 (6.4)
# Epoch 078/200 | Loss 0.0254 | Win/lose count 21.0/19.5 (1.5)
# Epoch 079/200 | Loss 0.0097 | Win/lose count 21.5/17.6 (3.9)
# Epoch 080/200 | Loss 0.0096 | Win/lose count 22.5/24.0 (-1.5)
# Epoch 081/200 | Loss 0.0291 | Win/lose count 22.0/22.4 (-0.4)
# Epoch 082/200 | Loss 0.0171 | Win/lose count 22.0/26.1 (-4.1)
# Epoch 083/200 | Loss 0.0158 | Win/lose count 24.5/17.5 (7.0)
# Epoch 084/200 | Loss 0.0285 | Win/lose count 30.0/20.3 (9.7)
# Epoch 085/200 | Loss 0.0116 | Win/lose count 22.0/26.1 (-4.1)
# Epoch 086/200 | Loss 0.0311 | Win/lose count 15.5/29.9 (-14.4)
# Epoch 087/200 | Loss 0.0205 | Win/lose count 23.0/26.1 (-3.1)
# Epoch 088/200 | Loss 0.0289 | Win/lose count 21.0/16.7 (4.3)
# Epoch 089/200 | Loss 0.0198 | Win/lose count 18.5/43.5 (-25.0)
# Epoch 090/200 | Loss 0.0171 | Win/lose count 27.5/20.4 (7.1)
# Epoch 091/200 | Loss 0.0092 | Win/lose count 22.5/22.6 (-0.1)
# Epoch 092/200 | Loss 0.0156 | Win/lose count 25.5/13.6 (11.9)
# Epoch 093/200 | Loss 0.0184 | Win/lose count 22.0/14.6 (7.4)
# Epoch 094/200 | Loss 0.0173 | Win/lose count 24.0/24.9 (-0.9)
# Epoch 095/200 | Loss 0.0285 | Win/lose count 22.5/20.9 (1.6)
# Epoch 096/200 | Loss 0.0099 | Win/lose count 22.0/20.2 (1.8)
# Epoch 097/200 | Loss 0.0173 | Win/lose count 20.0/19.8 (0.2)
# Epoch 098/200 | Loss 0.0097 | Win/lose count 20.5/24.7 (-4.2)
# Epoch 099/200 | Loss 0.0282 | Win/lose count 27.5/16.0 (11.5)
# Epoch 100/200 | Loss 0.0157 | Win/lose count 27.5/12.9 (14.6)
# Epoch 101/200 | Loss 0.0149 | Win/lose count 18.0/26.2 (-8.2)
# Epoch 102/200 | Loss 0.0113 | Win/lose count 19.5/33.4 (-13.9)
# Epoch 103/200 | Loss 0.0167 | Win/lose count 29.0/16.5 (12.5)
# Epoch 104/200 | Loss 0.0248 | Win/lose count 17.0/21.9 (-4.9)
# Epoch 105/200 | Loss 0.0090 | Win/lose count 20.5/29.6 (-9.1)
# Epoch 106/200 | Loss 0.0089 | Win/lose count 21.5/20.6 (0.9)
# Epoch 107/200 | Loss 0.0149 | Win/lose count 24.0/22.6 (1.4)
# Epoch 108/200 | Loss 0.0170 | Win/lose count 19.0/16.8 (2.2)
# Epoch 109/200 | Loss 0.0250 | Win/lose count 26.5/19.8 (6.7)
# Epoch 110/200 | Loss 0.0101 | Win/lose count 28.0/13.6 (14.4)
# Epoch 111/200 | Loss 0.0154 | Win/lose count 24.5/17.4 (7.1)
# Epoch 112/200 | Loss 0.0194 | Win/lose count 15.0/27.2 (-12.2)
# Epoch 113/200 | Loss 0.0092 | Win/lose count 25.5/20.1 (5.4)
# Epoch 114/200 | Loss 0.0145 | Win/lose count 20.0/24.2 (-4.2)
# Epoch 115/200 | Loss 0.0097 | Win/lose count 25.5/17.8 (7.7)
# Epoch 116/200 | Loss 0.0070 | Win/lose count 21.5/23.8 (-2.3)
# Epoch 117/200 | Loss 0.0375 | Win/lose count 24.5/23.8 (0.7)
# Epoch 118/200 | Loss 0.0176 | Win/lose count 27.5/14.0 (13.5)
# Epoch 119/200 | Loss 0.0142 | Win/lose count 24.0/20.8 (3.2)
# Epoch 120/200 | Loss 0.0226 | Win/lose count 25.0/28.2 (-3.2)
# Epoch 121/200 | Loss 0.0188 | Win/lose count 28.5/15.2 (13.3)
# Epoch 122/200 | Loss 0.0117 | Win/lose count 19.0/22.8 (-3.8)
# Epoch 123/200 | Loss 0.0296 | Win/lose count 25.5/16.9 (8.6)
# Epoch 124/200 | Loss 0.0122 | Win/lose count 19.0/33.6 (-14.6)
# Epoch 125/200 | Loss 0.0152 | Win/lose count 22.0/18.0 (4.0)
# Epoch 126/200 | Loss 0.0299 | Win/lose count 25.0/18.3 (6.7)
# Epoch 127/200 | Loss 0.0170 | Win/lose count 25.0/26.0 (-1.0)
# Epoch 128/200 | Loss 0.0176 | Win/lose count 21.0/20.3 (0.7)
# Epoch 129/200 | Loss 0.0173 | Win/lose count 29.5/11.1 (18.4)
# Epoch 130/200 | Loss 0.0218 | Win/lose count 26.0/19.9 (6.1)
# Epoch 131/200 | Loss 0.0244 | Win/lose count 21.5/20.5 (1.0)
# Epoch 132/200 | Loss 0.0159 | Win/lose count 24.0/20.7 (3.3)
# Epoch 133/200 | Loss 0.0081 | Win/lose count 24.5/18.8 (5.7)
# Epoch 134/200 | Loss 0.0277 | Win/lose count 26.0/16.9 (9.1)
# Epoch 135/200 | Loss 0.0168 | Win/lose count 24.0/15.6 (8.4)
# Epoch 136/200 | Loss 0.0276 | Win/lose count 20.5/29.0 (-8.5)
# Epoch 137/200 | Loss 0.0149 | Win/lose count 27.5/17.0 (10.5)
# Epoch 138/200 | Loss 0.0176 | Win/lose count 25.5/21.2 (4.3)
# Epoch 139/200 | Loss 0.0097 | Win/lose count 29.0/16.7 (12.3)
# Epoch 140/200 | Loss 0.0138 | Win/lose count 18.5/23.8 (-5.3)
# Epoch 141/200 | Loss 0.0259 | Win/lose count 21.0/15.3 (5.7)
# Epoch 142/200 | Loss 0.0107 | Win/lose count 25.0/23.8 (1.2)
# Epoch 143/200 | Loss 0.0215 | Win/lose count 29.5/19.9 (9.6)
# Epoch 144/200 | Loss 0.0187 | Win/lose count 24.0/17.5 (6.5)
# Epoch 145/200 | Loss 0.0257 | Win/lose count 22.0/21.9 (0.1)
# Epoch 146/200 | Loss 0.0189 | Win/lose count 20.5/23.9 (-3.4)
# Epoch 147/200 | Loss 0.0186 | Win/lose count 31.0/18.3 (12.7)
# Epoch 148/200 | Loss 0.0209 | Win/lose count 23.5/19.4 (4.1)
# Epoch 149/200 | Loss 0.0201 | Win/lose count 25.5/22.0 (3.5)
# Epoch 150/200 | Loss 0.0160 | Win/lose count 24.0/24.6 (-0.6)
# Epoch 151/200 | Loss 0.0324 | Win/lose count 18.5/23.1 (-4.6)
# Epoch 152/200 | Loss 0.0281 | Win/lose count 24.0/23.8 (0.2)
# Epoch 153/200 | Loss 0.0311 | Win/lose count 22.5/18.6 (3.9)
# Epoch 154/200 | Loss 0.0162 | Win/lose count 25.0/16.6 (8.4)
# Epoch 155/200 | Loss 0.0075 | Win/lose count 23.0/21.0 (2.0)
# Epoch 156/200 | Loss 0.0242 | Win/lose count 24.5/18.1 (6.4)
# Epoch 157/200 | Loss 0.0152 | Win/lose count 24.0/23.2 (0.8)
# Epoch 158/200 | Loss 0.0165 | Win/lose count 21.5/18.3 (3.2)
# Epoch 159/200 | Loss 0.0245 | Win/lose count 20.5/27.2 (-6.7)
# Epoch 160/200 | Loss 0.0133 | Win/lose count 21.5/31.5 (-10.0)
# Epoch 161/200 | Loss 0.0262 | Win/lose count 21.0/20.8 (0.2)
# Epoch 162/200 | Loss 0.0161 | Win/lose count 22.0/18.5 (3.5)
# Epoch 163/200 | Loss 0.0162 | Win/lose count 23.0/17.1 (5.9)
# Epoch 164/200 | Loss 0.0156 | Win/lose count 21.5/23.7 (-2.2)
# Epoch 165/200 | Loss 0.0249 | Win/lose count 21.5/38.2 (-16.7)
# Epoch 166/200 | Loss 0.0194 | Win/lose count 26.5/20.6 (5.9)
# Epoch 167/200 | Loss 0.0232 | Win/lose count 24.0/23.5 (0.5)
# Epoch 168/200 | Loss 0.0158 | Win/lose count 22.5/23.1 (-0.6)
# Epoch 169/200 | Loss 0.0240 | Win/lose count 26.5/22.0 (4.5)
# Epoch 170/200 | Loss 0.0118 | Win/lose count 21.5/15.1 (6.4)
# Epoch 171/200 | Loss 0.0217 | Win/lose count 22.0/26.2 (-4.2)
# Epoch 172/200 | Loss 0.0169 | Win/lose count 20.5/15.5 (5.0)
# Epoch 173/200 | Loss 0.0142 | Win/lose count 19.5/18.1 (1.4)
# Epoch 174/200 | Loss 0.0230 | Win/lose count 23.5/16.4 (7.1)
# Epoch 175/200 | Loss 0.0194 | Win/lose count 22.0/18.6 (3.4)
# Epoch 176/200 | Loss 0.0139 | Win/lose count 27.0/21.8 (5.2)
# Epoch 177/200 | Loss 0.0280 | Win/lose count 24.5/13.2 (11.3)
# Epoch 178/200 | Loss 0.0190 | Win/lose count 25.5/16.4 (9.1)
# Epoch 179/200 | Loss 0.0231 | Win/lose count 20.0/24.2 (-4.2)
# Epoch 180/200 | Loss 0.0271 | Win/lose count 18.5/28.5 (-10.0)
# Epoch 181/200 | Loss 0.0317 | Win/lose count 19.0/27.7 (-8.7)
# Epoch 182/200 | Loss 0.0145 | Win/lose count 28.0/17.8 (10.2)
# Epoch 183/200 | Loss 0.0152 | Win/lose count 24.0/21.1 (2.9)
# Epoch 184/200 | Loss 0.0294 | Win/lose count 13.5/71.3 (-57.8)
# Epoch 185/200 | Loss 0.0203 | Win/lose count 21.0/23.3 (-2.3)
# Epoch 186/200 | Loss 0.0099 | Win/lose count 21.5/20.8 (0.7)
# Epoch 187/200 | Loss 0.0291 | Win/lose count 28.0/21.5 (6.5)
# Epoch 188/200 | Loss 0.0264 | Win/lose count 18.0/18.0 (0.0)
# Epoch 189/200 | Loss 0.0093 | Win/lose count 24.5/20.6 (3.9)
# Epoch 190/200 | Loss 0.0211 | Win/lose count 18.5/31.6 (-13.1)
# Epoch 191/200 | Loss 0.0207 | Win/lose count 22.5/21.6 (0.9)
# Epoch 192/200 | Loss 0.0083 | Win/lose count 23.0/18.6 (4.4)
# Epoch 193/200 | Loss 0.0076 | Win/lose count 25.5/22.1 (3.4)
# Epoch 194/200 | Loss 0.0303 | Win/lose count 23.0/25.3 (-2.3)
# Epoch 195/200 | Loss 0.0296 | Win/lose count 19.5/23.5 (-4.0)
# Epoch 196/200 | Loss 0.0264 | Win/lose count 21.5/30.4 (-8.9)
# Epoch 197/200 | Loss 0.0157 | Win/lose count 23.5/15.8 (7.7)
# Epoch 198/200 | Loss 0.0159 | Win/lose count 24.5/20.2 (4.3)
# Epoch 199/200 | Loss 0.0191 | Win/lose count 23.0/15.6 (7.4)

# %%
# Evaluation
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
test(agent,env,epochs_test,prefix='cnn_test_explore')
# Out:
# Win/lose count 27.5/3.0. Average score (24.5)
# Win/lose count 26.5/3.0. Average score (24.0)
# Win/lose count 22.0/2.0. Average score (22.666666666666668)
# Win/lose count 19.0/3.0. Average score (21.0)
# Win/lose count 27.0/3.0. Average score (21.6)
# Win/lose count 28.0/3.0. Average score (22.166666666666668)
# Win/lose count 22.5/5.0. Average score (21.5)
# Win/lose count 25.0/6.0. Average score (21.1875)
# Win/lose count 26.0/2.0. Average score (21.5)
# Win/lose count 18.5/3.0. Average score (20.9)
# Final score: 20.9

# %%
HTML(display_videos('cnn_test_explore5.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __BONUS question__ Use the expert DQN from the previous question to generate some winning games. Train a model that mimicks its behavior. Compare the performances.

# %% [markdown]
# ***
